# %% [markdown]
# # Project Title: Predictive Maintenance for Industrial Milling Machines Using Deep Learning-Based Anomaly Detection

# %% [markdown]
# ![DL Project Theme](https://drive.google.com/uc?export=view&id=1YCc6YhJi9lUke844SDI1oIluvrtocNqA)

# %% [markdown]
# ## Table of Contents
# - 1.Introduction
# - 2.Background and state-of-the-art
# - 3.Problem Statement
# - 4.Dataset Description
# - 5.Solution/Methodology/Neural Net Architecture
# - 6.Theoretical Analysis
# - 7.Data Preprocessing and Training Methodology
# - 8.Experimental Results
# - 9.📌Inferences/Insights Obtained/Difficulties faced📌
#     - Report - https://www.overleaf.com/project/6961ee0a7991b078b488d4f1
# - 10.🔗 References 🔗

# %% [markdown]
# ## 1.Introduction

# %% [markdown]
# ## 2.Background and state-of-the-art

# %% [markdown]
# ## 3.Problem Statement

# %% [markdown]
# ## 4.Dataset Description

# %% [markdown]
# ## 5.Solution/Methodology/Neural Net Architecture

# %% [markdown]
# ## 6.Theoretical Analysis

# %% [markdown]
# ## 7.Data Preprocessing and Training Methodology

# %% [markdown]
# ## 8.Experimental Results

# %% [markdown]
# ## 9.📌Inferences/Insights Obtained/Difficulties faced 📌
# - Report : https://www.overleaf.com/project/6961ee0a7991b078b488d4f1

# %% [markdown]
# ## 10.🔗 References 🔗
